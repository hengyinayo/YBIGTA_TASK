# %% [markdown]
# # Pandas
# (데이터 타입이 같지 않아도 됨)
# - Numpy를 기반으로 하는 파이썬 데이터 분석 라이브러리
# - 행과 열로 이루어진 데이터 객체를 만들 수 있음
# - Series와 DataFrame 2가지 객체가 있음 <br>
# #### 1. Series
# - Index와 Value가 1:1 대응인 1차원 배열 형태 <br>
# #### 2. DataFrame
# - Index와 Value와 Column으로 이루어진 데이터 타입
# - 행과 열로 만들어지는 2차원 배열 구조
# - Column은 Series로 이루어지기 때문에, 정렬된 Series 객체의 연속으로 볼 수 있음
# - 엑셀의 테이블 형태과 유사함

# %%
# !pip install pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Series

# %% [markdown]
# ### 1-1. Series 생성

# %% [markdown]
# #### 1) 리스트로 생성

# %%
# 기본적으로 index는 0부터 부여
series1 = pd.Series([1, 6, 7, 3])
series1
# Out:
# 0    1
# 1    6
# 2    7
# 3    3
# dtype: int64

# %%
# 직접 index 지정 가능
series1_ = pd.Series([1, 6, 7, 3], index=["A","B","C","D"])
series1_
# Out:
# A    1
# B    6
# C    7
# D    3
# dtype: int64

# %%
# 자료형이 같을 필요는 없으나 dtype은 object로 반환 (자료 타입이 다르면 object type)
series3 = pd.Series((1, 6, 'a', 'b'))
series3
# Out:
# 0    1
# 1    6
# 2    a
# 3    b
# dtype: object

# %% [markdown]
# #### 2) 딕셔너리로 생성

# %%
# key 값으로 인덱스 지정
series2 = pd.Series({'A' : 90, 'B' : 80, 'C' : 70, 'D': 60})
series2
# Out:
# A    90
# B    80
# C    70
# D    60
# dtype: int64

# %% [markdown]
# #### 3) 튜플로 생성

# %%
series4 = pd.Series((90, 80, 70, 60), index=['A','B','C','D'])
series4
# Out:
# A    90
# B    80
# C    70
# D    60
# dtype: int64

# %% [markdown]
# ### 1-2. 간단한 확인 메소드
#
# |함수|설명|
# |--|--|
# |Series.values|값을 리스트로 반환|
# |Series.index|인덱스 확인|
# |Series.dtypes|자료형 확인|
# |Series.name|시리즈 이름 설정|
# |Series.index.name|인덱스 이름 설정|

# %%
# values: 값을 리스트로 반환 (안의 값 확인)
series1.values
# Out:
# array([1, 6, 7, 3])

# %%
# index: 인덱스 확인 (수치형인 인덱스일 경우 인덱스의 start/stop/step 반환)
series1.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
 # index: 인덱스 확인 (수치형이 아닌 인덱스일 경우 인덱스를 리스트로 반환)
series2.index #(자료형 확인 가능)
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
# dtypes: 자료형 확인
series1.dtypes
# Out:
# dtype('int64')

# %%
# 자료형이 여러 개일 경우 dtype은 object로 반환
series3.dtypes
# Out:
# dtype('O')

# %%
# 시리즈 이름, 인덱스 이름 설정 가능
series2.name = '학점 기준'
series2.index.name = '학점' # index에도 이름 붙일 수 있다
series2
# Out:
# 학점
# A    90
# B    80
# C    70
# D    60
# Name: 학점 기준, dtype: int64

# %% [markdown]
# ### 1-3. Series 인덱싱

# %%
# 인덱스 이름을 리스트로 설정해 전체 인덱스 변경 가능 (인덱스 이름으로 인덱싱 가능)
series1.index = ['W', 'X', 'Y', 'Z']
series1
# Out:
# W    1
# X    6
# Y    7
# Z    3
# dtype: int64

# %%
series1.index
# Out:
# Index(['W', 'X', 'Y', 'Z'], dtype='object')

# %% [markdown]
# #### 인덱싱 방법

# %% [markdown]
# ##### 1) index 이름을 통해 인덱싱

# %%
series2
# Out:
# 학점
# A    90
# B    80
# C    70
# D    60
# Name: 학점 기준, dtype: int64

# %%
# 1.<index 이름>
series2.A
# Out:
# 90

# %%
# 2. ['<index 이름>'] -> # 1.과 같은 값 반환
series2['A']
# Out:
# 90

# %%
# value 수정
series2['A']=95
series2
# Out:
# 학점
# A    95
# B    80
# C    70
# D    60
# Name: 학점 기준, dtype: int64

# %%
# 여러 개 한꺼번에 인덱싱 가능
series2[['A', 'C']]
# Out:
# 학점
# A    95
# C    70
# Name: 학점 기준, dtype: int64

# %%
# 여러 values 동시에 수정
series2[['B', 'C']]=[85,75]
series2
# Out:
# 학점
# A    95
# B    85
# C    75
# D    60
# Name: 학점 기준, dtype: int64

# %% [markdown]
# ##### 2) 자료의 위치를 통해 인덱싱

# %%
series2[0]
# Out:
# 95

# %%
# 여러 개 한꺼번에 인덱싱 가능 (리스트 처럼)
series2[[0,2]]
# Out:
# 학점
# A    95
# C    75
# Name: 학점 기준, dtype: int64

# %% [markdown]
# ### 1-4. Series 슬라이싱

# %%
# 인덱스 이름을 통해 슬라이싱
series2["A":"C"]
# Out:
# 학점
# A    95
# B    85
# C    75
# Name: 학점 기준, dtype: int64

# %%
# offset index
series2[0:3]
# Out:
# 학점
# A    95
# B    85
# C    75
# Name: 학점 기준, dtype: int64

# %% [markdown]
# ### 1-5. Data filtering

# %%
series2 >= 80
# Out:
# 학점
# A     True
# B     True
# C    False
# D    False
# Name: 학점 기준, dtype: bool

# %%
# 데이터 필터링
series2[series2 >= 80]
# Out:
# 학점
# A    95
# B    85
# Name: 학점 기준, dtype: int64

# %% [markdown]
# ### 1-6. Series 연산

# %%
series_1 = pd.Series([1, 2, 3, 4]) # 길이가 같아야됨
series_2 = pd.Series([5, 6, 7, 8])

# %%
# series끼리 연산 가능
print(np.dot(series_1, series_2))
# Out:
# 70

# %%
# numpy 함수를 써도 됨
print(np.subtract(series_1 , series_2))
print("")
print(series_1.sub(series_2))
# Out:
# 0   -4
# 1   -4
# 2   -4
# 3   -4
# dtype: int64
#
# 0   -4
# 1   -4
# 2   -4
# 3   -4
# dtype: int64

# %%
# 인덱스를 기준으로 연산하기 때문에 인덱스 값이 다르면 NaN 반환 (즉, 연산이 안됨)
series1 + series2
# Out:
# A   NaN
# B   NaN
# C   NaN
# D   NaN
# W   NaN
# X   NaN
# Y   NaN
# Z   NaN
# dtype: float64

# %% [markdown]
# ### 1-7. Series 변형

# %% [markdown]
# #### concat

# %%
S1 = pd.Series([1,2,3])
S2 = pd.Series([4,5,6])

# %%
# default는 axis=0 -> 행 방향으로 순서의 변환 없이 결합
pd.concat([S1,S2]) # 인덱스가 겹칠 수 있음
# Out:
# 0    1
# 1    2
# 2    3
# 0    4
# 1    5
# 2    6
# dtype: int64

# %%
# axis=1 -> 열 방향 결합
pd.concat([S1,S2], axis=1)
# Out:
#    0  1
# 0  1  4
# 1  2  5
# 2  3  6

# %% [markdown]
# #### drop (시리즈에서 요소 삭제?)

# %%
S1
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
# index가 수치형일 때: 인덱스 값을 drop()에 넣어줌
S = S1.drop(0)
S
# Out:
# 1    2
# 2    3
# dtype: int64

# %%
S.index = ["a","b"]
S
# Out:
# a    2
# b    3
# dtype: int64

# %%
# index를 수치형이 아닌 자료형으로 지정해 주었을 때: 인덱스 이름을 drop()에 넣어줌
# S.drop(0) -> error (인덱스가 숫자가 아닌데, 숫자를 넣어주면 에러)
S=S.drop("a")
S
# Out:
# b    3
# dtype: int64

# %% [markdown]
# ### 1-8. Series 결측치 처리
#
# |함수|설명|
# |--|--|
# |.isnull()|null인 값에 대해 True를 반환|
# |.notnull()|null이 아닌 값에 대해 True를 반환|
# |.dropna()|null 값 제거|
# |.fillna()|null 값 대체|

# %%
Series = pd.Series([3,4,np.nan,5,6,np.nan])
Series
# Out:
# 0    3.0
# 1    4.0
# 2    NaN
# 3    5.0
# 4    6.0
# 5    NaN
# dtype: float64

# %%
# Series의 각 Value 값이 결측치인지 아닌지 확인 가능
# .isnull(): null인 값에 대해 True를 반환
Series.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# dtype: bool

# %%
#결측치 개수
Series.isnull().sum() # true인 값만 연산 수행
# Out:
# 2

# %%
# .notnull(): null이 아닌 값에 대해 True를 반환
Series.notnull()
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# 5    False
# dtype: bool

# %%
# 결측치 아닌 values 개수
#--------------------------
Series.notnull().sum()
#--------------------------
# Out:
# 4

# %%
# null이 아닌 값들만 가져오기
Series[Series.notnull()]
# Out:
# 0    3.0
# 1    4.0
# 3    5.0
# 4    6.0
# dtype: float64

# %%
# .dropna(): null 값 제거
Series.dropna()
# Out:
# 0    3.0
# 1    4.0
# 3    5.0
# 4    6.0
# dtype: float64

# %%
# .fillna(): null 값 대체
Series.fillna(5.5)
# Out:
# 0    3.0
# 1    4.0
# 2    5.5
# 3    5.0
# 4    6.0
# 5    5.5
# dtype: float64

# %%
# 결측치를 평균값으로 대체 Series.mean() 사용!! (결측치할때 평균값을 넣어주는 경우가 많음)
#--------------------------------------

#--------------------------------------
# Out:
# 0    3.0
# 1    4.0
# 2    4.5
# 3    5.0
# 4    6.0
# 5    4.5
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## 2. DataFrame
#
# column : 열(세로) / row : 행(가로)

# %% [markdown]
# ### 2-1. 데이터프레임 생성

# %% [markdown]
# #### 1) 리스트로 생성

# %%
df1 = pd.DataFrame(columns=["Food","Price"]) # column을 먼저 지정해주어야함

df1["Food"] = ["마라샹궈","마라탕","아이스크림","아이셔"]
df1["Price"] = [15000,8000,1000,"판매종료"] # 데이터 타입이 달라도 되니깐 (개수는 똑같아야함)

df1
# Out:
#     Food  Price
# 0   마라샹궈  15000
# 1    마라탕   8000
# 2  아이스크림   1000
# 3    아이셔   판매종료

# %% [markdown]
# #### 2) 딕셔너리로 생성

# %%
food = ["꿔바로우", "순대국밥"]
price = [16000, 8000]

dic = {"Food": food, "Price": price} # Food라는 column에 food 요소들을 넣어주고, ...
df2 = pd.DataFrame(dic, index=['A','B'])
df2
# Out:
#    Food  Price
# A  꿔바로우  16000
# B  순대국밥   8000

# %%
# 칼럼을 인덱스로 설정
df2.set_index("Food")
# Out:
#       Price
# Food
# 꿔바로우  16000
# 순대국밥   8000

# %% [markdown]
# ### 2-2. 데이터프레임 인덱싱

# %%
# 앞서 말했듯이 column이 매우 중요
df2
# Out:
#    Food  Price
# A  꿔바로우  16000
# B  순대국밥   8000

# %% [markdown]
# #### 1) 바로 인덱싱

# %%
# df["column"]: 열 이름으로 접근
df2['Food']
# df2.Food
# Out:
# A    꿔바로우
# B    순대국밥
# Name: Food, dtype: object

# %%
# df[열 이름 리스트]: 리스트로 열 인덱싱
df2[['Food','Price']]
# Out:
#    Food  Price
# A  꿔바로우  16000
# B  순대국밥   8000

# %%
# dataframe은 행 이름으로 인덱싱 불가능
# df2["A"] -> Error

# %%
# dataframe의 행 이름은 슬라이싱으로만 접근 가능
df2["A":"A"]
# Out:
#    Food  Price
# A  꿔바로우  16000

# %% [markdown]
# #### 2) loc[ ]

# %%
# df.loc["row","column"]: 행/열의 이름으로 접근
df2.loc["A"] # 행의 이름으로 접근
# Out:
# Food      꿔바로우
# Price    16000
# Name: A, dtype: object

# %%
df2.loc[["A","B"]] # 행의 이름을 리스트로 접근
# Out:
#    Food  Price
# A  꿔바로우  16000
# B  순대국밥   8000

# %%
df2.loc["A":"B"] # 행의 이름 리스트 슬라이싱
# Out:
#    Food  Price
# A  꿔바로우  16000
# B  순대국밥   8000

# %%
df2.loc[:,"Price"] # 열의 이름으로 접근 (모든 행에 대해서 Price를 갖고 와라)
# Out:
# A    16000
# B     8000
# Name: Price, dtype: int64

# %%
df2.loc[:,["Food", "Price"]] # 열의 이름을 리스트로 접근 (모든 행에 대해서 Food, Price를 갖고 와라)
# Out:
#    Food  Price
# A  꿔바로우  16000
# B  순대국밥   8000

# %%
df2.loc[:,"Food":"Price"] # 열의 이름 리스트 슬라이싱
# Out:
#    Food  Price
# A  꿔바로우  16000
# B  순대국밥   8000

# %%
df2.loc["A", "Price"] # 행의 이름, 열의 이름 인덱싱
# Out:
# 16000

# %%
#요소 바꾸기
df2.loc["A","Price"]=12000
df2
# Out:
#    Food  Price
# A  꿔바로우  12000
# B  순대국밥   8000

# %% [markdown]
# #### 3) iloc[ ] (i를 붙여주면 숫자로 접근 가능)

# %%
# df.iloc[0,0]: 행/열의 인덱스 값으로 접근 (0부터 시작)
df2.iloc[0] # 행의 인덱스 값으로 접근
# Out:
# Food      꿔바로우
# Price    12000
# Name: A, dtype: object

# %%
df1.iloc[[0,2]] # 행의 인덱스 값을 리스트로 접근
# Out:
#     Food  Price
# 0   마라샹궈  15000
# 2  아이스크림   1000

# %%
df1.iloc[1:3,0] # 행의 인덱스 값 리스트 슬라이싱
# Out:
# 1      마라탕
# 2    아이스크림
# Name: Food, dtype: object

# %%
df2.iloc[:,0] # 열의 인덱스 값으로 접근
# Out:
# A    꿔바로우
# B    순대국밥
# Name: Food, dtype: object

# %%
df1.iloc[:,[0,1]] # 열의 인덱스 값을 리스트로 접근
# Out:
#     Food  Price
# 0   마라샹궈  15000
# 1    마라탕   8000
# 2  아이스크림   1000
# 3    아이셔   판매종료

# %%
df2.iloc[:,0:1] # 열의 인덱스 값 리스트 슬라이싱
# Out:
#    Food
# A  꿔바로우
# B  순대국밥

# %%
df2.iloc[0,1] # 행의 인덱스 값, 열의 인덱스 값 인덱싱
# Out:
# 12000

# %% [markdown]
# #### 4) 조건으로 접근

# %%
# 조건으로 접근
df2[df2.Price > 10000]['Price']
# Out:
# A    12000
# Name: Price, dtype: int64

# %% [markdown]
# ### 2-3. 데이터프레임 추가, 삭제

# %% [markdown]
# #### 추가

# %%
df1
# Out:
#     Food  Price
# 0   마라샹궈  15000
# 1    마라탕   8000
# 2  아이스크림   1000
# 3    아이셔   판매종료

# %%
# loc을 이용해 변경
df1.loc[3] = ["꿔바로우", "12000"]
df1
# Out:
#     Food  Price
# 0   마라샹궈  15000
# 1    마라탕   8000
# 2  아이스크림   1000
# 3   꿔바로우  12000

# %%
# loc을 이용해 추가 (없는 자리에다가 넣어주면 새로 생성 가능)
df1.loc[4] = ["볶음밥", "7000"]
df1
# Out:
#     Food  Price
# 0   마라샹궈  15000
# 1    마라탕   8000
# 2  아이스크림   1000
# 3   꿔바로우  12000
# 4    볶음밥   7000

# %%
# 바로 변경
df1["Price"][2] = 1200
df1
# Out:
#     Food  Price
# 0   마라샹궈  15000
# 1    마라탕   8000
# 2  아이스크림   1200
# 3   꿔바로우  12000
# 4    볶음밥   7000

# %% [markdown]
# #### Row(행) 삭제

# %%
# drop을 통해 삭제, default는 axis=0(행)
df1_ = df1.drop(2) # 원본 데이터를 변경하지 않음 (새로운 데이터 할당해줌)
df1_
# Out:
#    Food  Price
# 0  마라샹궈  15000
# 1   마라탕   8000
# 3  꿔바로우  12000
# 4   볶음밥   7000

# %%
# 해당 데이터프레임에서 삭제하는 방법: inplace=True
df1.drop(1, inplace=True)
df1
# df1 = df1.drop(1) -> error
# Out:
#     Food  Price
# 0   마라샹궈  15000
# 2  아이스크림   1200
# 3   꿔바로우  12000
# 4    볶음밥   7000

# %%
# reset_index를 통해 인덱스 재정렬
# 옵션이 없을 시에는 삭제된 index도 따로 index라는 column으로 저장됨
df1__ = df1.reset_index()
df1__
# Out:
#    index   Food  Price
# 0      0   마라샹궈  15000
# 1      2  아이스크림   1200
# 2      3   꿔바로우  12000
# 3      4    볶음밥   7000

# %%
# 다음과 같이 실행하면 저장하지 않음
df1 = df1.reset_index(drop=True) # drop true 해주면 index 깔끔하게 정렬
df1
# Out:
#     Food  Price
# 0   마라샹궈  15000
# 1  아이스크림   1200
# 2   꿔바로우  12000
# 3    볶음밥   7000

# %% [markdown]
# #### Column(열) 삭제

# %%
# axis=1로 열 삭제
df1__.drop("index", axis=1)
# Out:
#     Food  Price
# 0   마라샹궈  15000
# 1  아이스크림   1200
# 2   꿔바로우  12000
# 3    볶음밥   7000

# %% [markdown]
# ### 2-4. concat / merge

# %% [markdown]
# ####  concat

# %%
df1
# Out:
#     Food  Price
# 0   마라샹궈  15000
# 1  아이스크림   1200
# 2   꿔바로우  12000
# 3    볶음밥   7000

# %%
df2
# Out:
#    Food  Price
# A  꿔바로우  12000
# B  순대국밥   8000

# %%
# default는 axis=0: 행 방향(위아래)으로 결합
df3 = pd.concat([df1, df2])
df3
# Out:
#     Food  Price
# 0   마라샹궈  15000
# 1  아이스크림   1200
# 2   꿔바로우  12000
# 3    볶음밥   7000
# A   꿔바로우  12000
# B   순대국밥   8000

# %%
# axis=1: 열 방향(좌우)으로 결합
df4 = pd.concat([df2, df2], axis=1)
df4
# Out:
#    Food  Price  Food  Price
# A  꿔바로우  12000  꿔바로우  12000
# B  순대국밥   8000  순대국밥   8000

# %%
# 결합 방법은 join으로 지정, default 값은 'outer' (outer 합집합으로  생각)
# 'outer' -> concat했을 때 공통적 key 값이 없는 값은 null로 반환
pd.concat([df3,df2], axis=1)
# Out:
#     Food  Price  Food    Price
# 0   마라샹궈  15000   NaN      NaN
# 1  아이스크림   1200   NaN      NaN
# 2   꿔바로우  12000   NaN      NaN
# 3    볶음밥   7000   NaN      NaN
# A   꿔바로우  12000  꿔바로우  12000.0
# B   순대국밥   8000  순대국밥   8000.0

# %%
# 'inner' -> 공통적으로 존재하는 key 값만을 반환 (inner는 교집합으로 생각)
pd.concat([df3,df2], axis=1, join='inner')
# Out:
#    Food  Price  Food  Price
# A  꿔바로우  16000  꿔바로우  16000
# B  순대국밥   8000  순대국밥   8000

# %% [markdown]
# #### merge

# %% [markdown]
# #### concat과 merge의 차이?
# - concat은 단순히 물리적으로 이어붙임
# - merge는 각 데이터에 존재하는 고유값(key)을 기준으로 병합

# %% [markdown]
# #### merge 종류
# <img src="https://miro.medium.com/max/1400/1*9eH1_7VbTZPZd9jBiGIyNA.png" height="100px" width="300px">
# left, right은 어느 쪽을 중점으로 할거냐

# %%
df3
# Out:
#     Food  Price
# 0   마라샹궈  15000
# 1    마라탕   8000
# 2  아이스크림   1000
# 3    아이셔   판매종료
# A   꿔바로우  16000
# B   순대국밥   8000

# %%
df5 = pd.DataFrame({'Food': ['마라샹궈', '초밥', '부대찌개', '순대국밥'],
                    'Country': ['중국', '일본', '한국', '한국']})
df5
# Out:
#    Food Country
# 0  마라샹궈      중국
# 1    초밥      일본
# 2  부대찌개      한국
# 3  순대국밥      한국

# %%
# 결합 방법 how로 지정, default 값은 'inner'
# how='inner' -> key 값이 둘 다 있는 것만 병합
# on='Food' -> 기준으로 할 열 이름
pd.merge(df3, df5, how='inner', on='Food')
# Out:
#    Food  Price Country
# 0  마라샹궈  15000      중국
# 1  순대국밥   8000      한국

# %%
# how='outer' -> key 값이 한 데이터프레임에만 있어도 병합
pd.merge(df3, df5, how='outer', on='Food')
# Out:
#     Food  Price Country
# 0   마라샹궈  15000      중국
# 1    마라탕   8000     NaN
# 2  아이스크림   1000     NaN
# 3    아이셔   판매종료     NaN
# 4   꿔바로우  16000     NaN
# 5   순대국밥   8000      한국
# 6     초밥    NaN      일본
# 7   부대찌개    NaN      한국

# %%
# how='left' -> 왼쪽 데이터프레임의 'on' 기준
pd.merge(df3, df5, how='left', on='Food')
# Out:
#     Food  Price Country
# 0   마라샹궈  15000      중국
# 1    마라탕   8000     NaN
# 2  아이스크림   1000     NaN
# 3    아이셔   판매종료     NaN
# 4   꿔바로우  16000     NaN
# 5   순대국밥   8000      한국

# %%
# how='right' -> 오른쪽 데이터프레임의 'on' 기준
pd.merge(df3, df5, how='right', on='Food')
# Out:
#    Food  Price Country
# 0  마라샹궈  15000      중국
# 1    초밥    NaN      일본
# 2  부대찌개    NaN      한국
# 3  순대국밥   8000      한국

# %% [markdown]
# ### 2-5. 데이터 읽기, 저장하기 (titanic.csv)
# |함수|설명|
# |--|--|
# |pd.read_csv|csv 파일 불러오기|
# |df.head()|전체 데이터프레임에서 상위 5개 행 출력|
# |df.tail()|전체 데이터프레임에서 하위 5개 행 출력|
# |df.shape|데이터프레임의 행, 열 개수를 튜플로 반환|
# |df.info()|데이터프레임의 열의 데이터 타입, 전체 데이터 개수, 결측치 개수 확인|
# |df.astype()|데이터프레임의 모든 데이터 타입이 같을 때 전체를 한꺼번에 변경|
# |df.describe()|데이터프레임의 수치형 데이터를 갖는 열에 대한 통계값 확인|
# |df.columns|열 이름을 리스트로 반환|
# |df.to_csv()|csv 파일로 저장하기|

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 데이터 읽기
# path = ''
# titanic = pd.read_csv(path+'titanic.csv')
titanic = pd.read_csv('/content/drive/MyDrive/numpy,pandas/titanic.csv')

# %%
# head를 통해 데이터프레임 맨 앞부분 확인
# 기본 5개
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# tail을 통해 데이터프레임 맨 뒷부분 확인
# 기본 5개
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# default는 5개이지만 표시하는 개수를 조정 가능
# display를 사용해 print처럼 확인 가능 (pandas할때 display 사용하면 이쁘게 나옴)

display(titanic.head(2))
display(titanic.tail(2))
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 889          890         1       1  Behr, Mr. Karl Howell  male  26.0      0
# 890          891         0       3    Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket   Fare Cabin Embarked
# 889      0  111369  30.00  C148        C
# 890      0  370376   7.75   NaN        Q

# %%
# shape를 통해 데이터프레임의 row, column 개수 확인 가능
titanic.shape
# Out:
# (891, 12)

# %%
# info를 통해 nan과 데이터 타입, 전체 데이터 수 등 확인 가능 (각 column마다)
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# 데이터 타입 변경 가능
titanic.Survived = titanic.Survived.astype('object')
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
# describe를 이용하여 수치형 데이터를 갖는 열에 대한 통계값 확인 (수치형 데이터만 가능)
titanic.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000    2.308642   29.699118    0.523008    0.381594   32.204208
# std     257.353842    0.836071   14.526497    1.102743    0.806057   49.693429
# min       1.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000    3.000000   38.000000    1.000000    0.000000   31.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# columns을 이용하여 리스트 형태로 열 이름 확인
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# 불러오는 설정을 다르게 해서 csv의 일부분만 가져올 수 있음
titanic2= pd.read_csv("/content/drive/MyDrive/numpy,pandas/titanic.csv",
                      usecols=["PassengerId","Age", "Survived"], # 사용할 컬럼들 (지정 가능)
                      nrows=10, #가져올 행의 개수
                      index_col="PassengerId") # 인덱스로 지정할 컬럼명

titanic2
# 위에 지정한 3개의 컬럼만 들고 옴
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-38-647e6d990b96> in <cell line: 2>()
#       1 # 불러오는 설정을 다르게 해서 csv의 일부분만 가져올 수 있음
# ----> 2 titanic2= pd.read_csv("/content/drive/MyDrive/numpy,pandas/titanic.csv",
#       3                       usecols=["PassengerId","Age", "Survived"], # 사용할 컬럼들 (지정 가능)
#       4                       nrows=10 #가져올 행의 개수
#       5                       ) # 인덱스로 지정할 컬럼명
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     603
#     604     # Create the parser.
# --> 605     parser = TextFileReader(filepath_or_buffer, **kwds)
#     606
#     607     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1440
#    1441         self.handles: IOHandles | None = None
# -> 1442         self._engine = self._make_engine(f, self.engine)
#    1443
#    1444     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1733                 if "b" not in mode:
#    1734                     mode += "b"
# -> 1735             self.handles = get_handle(
#    1736                 f,
#    1737                 mode,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854         if ioargs.encoding and "b" not in ioargs.mode:
#     855             # Encoding
# --> 856             handle = open(
#     857                 handle,
#     858                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/numpy,pandas/titanic.csv'

# %%
# 저장하기: .to_csv (다시 파일로 만들어 줘야하니깐)
titanic2.to_csv("/content/drive/MyDrive/numpy,pandas/titanic2.csv", index=False) #read_csv와 마찬가지로, 경로 지정 가능 (titanic2.csv 이 부분은 파일명 원하는대로 지정)
# index=False를 하지 않으면 인덱스까지 새로운 컬럼(Unnamed: 0)으로 저장됨
# 이 경우, 인덱스인 PassengerId column이 저장
titanic2.to_csv("/content/drive/MyDrive/numpy,pandas/titanic3.csv") # 같은 titnaic2에 대해 2개의 파일로 생성

# %%
titanic2 = pd.read_csv('/content/drive/MyDrive/numpy,pandas/titanic2.csv')
titanic2 # 인덱스 false 해서 index 사라짐
# Out:
#    Survived   Age
# 0         0  22.0
# 1         1  38.0
# 2         1  26.0
# 3         1  35.0
# 4         0  35.0
# 5         0   NaN
# 6         0  54.0
# 7         0   2.0
# 8         1  27.0
# 9         1  14.0

# %%
titanic3 = pd.read_csv('/content/drive/MyDrive/numpy,pandas/titanic2.csv')
titanic3
# Out:
#    Survived   Age
# 0         0  22.0
# 1         1  38.0
# 2         1  26.0
# 3         1  35.0
# 4         0  35.0
# 5         0   NaN
# 6         0  54.0
# 7         0   2.0
# 8         1  27.0
# 9         1  14.0

# %% [markdown]
# ---

# %% [markdown]
# ### 2-6. 판다스 함수
# |함수|설명|
# |--|--|
# |df.apply()|전체 데이터프레임 또는 특정 열에 함수 적용|
# |df.sort_values()|값을 기준으로 정렬|
# |df.isnull()|결측치 확인 (null 값이라면 True, null 값이 아니라면 False 출력)|
# |df.isnull.sum()|각 컬럼별 결측치 개수 확인|
# |df.notnull()|결측치 확인 (null 값이 아니라면 True, null 값이라면 False 출력)|
# |df.dropna()|결측치가 있는 행, 열 제거|
# |df.fillna()|() 안의 값으로 결측치 대체|
# |df.unique()|데이터의 고유 값 출력|
# |df.value_counts()|고유 값 별 데이터 개수 출력|
# |df.groupby()|데이터를 그룹별로 분할|
# |df.groupby.size()|데이터를 그룹별로 분할한 후 그룹별 개수 확인|
# |df.groupby.agg()|데이터를 그룹별로 분할한 후 통계값 확인|

# %% [markdown]
# #### 1) apply

# %%
titanic.head(2)
# Out:
#    PassengerId Survived  Pclass  \
# 0            1        0       3
# 1            2        1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
# apply를 이용해 함수를 적용할 수 있음
def is_adult(age):
    if age < 20 :
        return 'not adult'
    if age >= 20 :
        return 'adult'

# %%
titanic['is_adult'] = titanic['Age'].apply(is_adult)  # 인위적으로 분류 할때 사용함
titanic.tail()
# Out:
#      PassengerId Survived  Pclass                                      Name  \
# 886          887        0       2                     Montvila, Rev. Juozas
# 887          888        1       1              Graham, Miss. Margaret Edith
# 888          889        0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890        1       1                     Behr, Mr. Karl Howell
# 890          891        0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked   is_adult
# 886    male  27.0      0      0      211536  13.00   NaN        S      adult
# 887  female  19.0      0      0      112053  30.00   B42        S  not adult
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S       None
# 889    male  26.0      0      0      111369  30.00  C148        C      adult
# 890    male  32.0      0      0      370376   7.75   NaN        Q      adult

# %% [markdown]
# ##### lambda 사용

# %%
df3['Price'] = df3['Price'].apply(lambda x : int(x)) # Price라는 컬럼을 int 형으로 바꿈

df3
# Out:
#     Food  Price
# 0   마라샹궈  15000
# 1  아이스크림   1200
# 2   꿔바로우  12000
# 3    볶음밥   7000
# A   꿔바로우  12000
# B   순대국밥   8000

# %%
# lambda 함수를 통해서도 쓸 수 있음
# 더 간단
titanic['is_adult'] = titanic['Age'].apply(lambda x: 'adult' if x >= 20 else 'not_adult')
titanic.head()
# Out:
#    PassengerId Survived  Pclass  \
# 0            1        0       3
# 1            2        1       1
# 2            3        1       3
# 3            4        1       1
# 4            5        0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked is_adult
# 0      0         A/5 21171   7.2500   NaN        S    adult
# 1      0          PC 17599  71.2833   C85        C    adult
# 2      0  STON/O2. 3101282   7.9250   NaN        S    adult
# 3      0            113803  53.1000  C123        S    adult
# 4      0            373450   8.0500   NaN        S    adult

# %%
titanic.tail()
# Out:
#      PassengerId Survived  Pclass                                      Name  \
# 886          887        0       2                     Montvila, Rev. Juozas
# 887          888        1       1              Graham, Miss. Margaret Edith
# 888          889        0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890        1       1                     Behr, Mr. Karl Howell
# 890          891        0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked   is_adult
# 886    male  27.0      0      0      211536  13.00   NaN        S      adult
# 887  female  19.0      0      0      112053  30.00   B42        S  not_adult
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S  not_adult
# 889    male  26.0      0      0      111369  30.00  C148        C      adult
# 890    male  32.0      0      0      370376   7.75   NaN        Q      adult

# %% [markdown]
# #### 2) sort_values

# %%
df3.sort_values('Price', ascending = False) # 특정 컬럼에 대해서 오름차순 또는 내림차순 정렬 가능
# Out:
#     Food  Price
# 0   마라샹궈  15000
# 2   꿔바로우  12000
# A   꿔바로우  12000
# B   순대국밥   8000
# 3    볶음밥   7000
# 1  아이스크림   1200

# %%
# 원하는 칼럼을 선택해 그것을 기준으로 오름차순 정렬: .sort_values()
titanic.sort_values('Pclass').head()
# Out:
#      PassengerId Survived  Pclass  \
# 445          446        1       1
# 310          311        1       1
# 309          310        1       1
# 307          308        1       1
# 306          307        1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 445                          Dodge, Master. Washington    male   4.0      0
# 310                     Hays, Miss. Margaret Bechstein  female  24.0      0
# 309                     Francatelli, Miss. Laura Mabel  female  30.0      0
# 307  Penasco y Castellana, Mrs. Victor de Satode (M...  female  17.0      1
# 306                            Fleming, Miss. Margaret  female   NaN      0
#
#      Parch    Ticket      Fare Cabin Embarked   is_adult
# 445      2     33638   81.8583   A34        S  not_adult
# 310      0     11767   83.1583   C54        C      adult
# 309      0  PC 17485   56.9292   E36        C      adult
# 307      0  PC 17758  108.9000   C65        C  not_adult
# 306      0     17421  110.8833   NaN        C  not_adult

# %%
# ascending=False로 하면 내림차순
titanic.sort_values('Pclass', ascending=False).head()
# Out:
#      PassengerId Survived  Pclass                            Name     Sex  \
# 0              1        0       3         Braund, Mr. Owen Harris    male
# 511          512        0       3               Webber, Mr. James    male
# 500          501        0       3                Calic, Mr. Petar    male
# 501          502        0       3             Canavan, Miss. Mary  female
# 502          503        0       3  O'Sullivan, Miss. Bridget Mary  female
#
#       Age  SibSp  Parch            Ticket    Fare Cabin Embarked   is_adult
# 0    22.0      1      0         A/5 21171  7.2500   NaN        S      adult
# 511   NaN      0      0  SOTON/OQ 3101316  8.0500   NaN        S  not_adult
# 500  17.0      0      0            315086  8.6625   NaN        S  not_adult
# 501  21.0      0      0            364846  7.7500   NaN        Q      adult
# 502   NaN      0      0            330909  7.6292   NaN        Q  not_adult

# %% [markdown]
# ### null 값 확인 및 처리

# %%
titanic.info() # 결측치 확인 가능 결측치 처리하는 것도 중요
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  is_adult     891 non-null    object
# dtypes: float64(2), int64(4), object(7)
# memory usage: 90.6+ KB

# %%
# .isnull(): null 값 확인
titanic[titanic["Age"].isnull()] # Age가 null 값인 애들만 뜸
# Out:
#      PassengerId Survived  Pclass                                      Name  \
# 5              6        0       3                          Moran, Mr. James
# 17            18        1       2              Williams, Mr. Charles Eugene
# 19            20        1       3                   Masselmani, Mrs. Fatima
# 26            27        0       3                   Emir, Mr. Farred Chehab
# 28            29        1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...      ...     ...                                       ...
# 859          860        0       3                          Razi, Mr. Raihed
# 863          864        0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869        0       3               van Melkebeke, Mr. Philemon
# 878          879        0       3                        Laleff, Mr. Kristo
# 888          889        0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked   is_adult
# 5      male  NaN      0      0      330877   8.4583   NaN        Q  not_adult
# 17     male  NaN      0      0      244373  13.0000   NaN        S  not_adult
# 19   female  NaN      0      0        2649   7.2250   NaN        C  not_adult
# 26     male  NaN      0      0        2631   7.2250   NaN        C  not_adult
# 28   female  NaN      0      0      330959   7.8792   NaN        Q  not_adult
# ..      ...  ...    ...    ...         ...      ...   ...      ...        ...
# 859    male  NaN      0      0        2629   7.2292   NaN        C  not_adult
# 863  female  NaN      8      2    CA. 2343  69.5500   NaN        S  not_adult
# 868    male  NaN      0      0      345777   9.5000   NaN        S  not_adult
# 878    male  NaN      0      0      349217   7.8958   NaN        S  not_adult
# 888  female  NaN      1      2  W./C. 6607  23.4500   NaN        S  not_adult
#
# [177 rows x 13 columns]

# %%
# .isnull().sum(): null 값 개수 확인
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# is_adult         0
# dtype: int64

# %%
# null 값이 없는 행만 보고 싶다면? notnull() 사용!!
#------------------------------------
# titanic[titanic["Age"].isnull()] 여기에 notnull titanic[titanic["Age"].isnull()[!@#$]] (여기에 조건 더 첨부 가능)
#------------------------------------
# Out:
#      PassengerId Survived  Pclass  \
# 0              1        0       3
# 1              2        1       1
# 2              3        1       3
# 3              4        1       1
# 4              5        0       3
# ..           ...      ...     ...
# 886          887        0       2
# 887          888        1       1
# 888          889        0       3
# 889          890        1       1
# 890          891        0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked   is_adult
# 0        0         A/5 21171   7.2500   NaN        S      adult
# 1        0          PC 17599  71.2833   C85        C      adult
# 2        0  STON/O2. 3101282   7.9250   NaN        S      adult
# 3        0            113803  53.1000  C123        S      adult
# 4        0            373450   8.0500   NaN        S      adult
# ..     ...               ...      ...   ...      ...        ...
# 886      0            211536  13.0000   NaN        S      adult
# 887      0            112053  30.0000   B42        S  not_adult
# 888      2        W./C. 6607  23.4500   NaN        S  not_adult
# 889      0            111369  30.0000  C148        C      adult
# 890      0            370376   7.7500   NaN        Q      adult
#
# [891 rows x 13 columns]

# %% [markdown]
# #### 3) dropna

# %%
titanic[titanic['Age'].isnull()].head() # dropna로 결측치 없애기
# Out:
#     PassengerId Survived  Pclass                           Name     Sex  Age  \
# 5             6        0       3               Moran, Mr. James    male  NaN
# 17           18        1       2   Williams, Mr. Charles Eugene    male  NaN
# 19           20        1       3        Masselmani, Mrs. Fatima  female  NaN
# 26           27        0       3        Emir, Mr. Farred Chehab    male  NaN
# 28           29        1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN
#
#     SibSp  Parch  Ticket     Fare Cabin Embarked   is_adult
# 5       0      0  330877   8.4583   NaN        Q  not_adult
# 17      0      0  244373  13.0000   NaN        S  not_adult
# 19      0      0    2649   7.2250   NaN        C  not_adult
# 26      0      0    2631   7.2250   NaN        C  not_adult
# 28      0      0  330959   7.8792   NaN        Q  not_adult

# %%
titanic_notnull = titanic.dropna() # 결측치가 있는 행 모두 제거
titanic_notnull.head(20)
# Out:
#      PassengerId Survived  Pclass  \
# 1              2        1       1
# 3              4        1       1
# 6              7        0       1
# 10            11        1       3
# 11            12        1       1
# 21            22        1       2
# 23            24        1       1
# 27            28        0       1
# 52            53        1       1
# 54            55        0       1
# 62            63        0       1
# 66            67        1       2
# 75            76        0       3
# 88            89        1       1
# 92            93        0       1
# 96            97        0       1
# 97            98        1       1
# 102          103        0       1
# 110          111        0       1
# 118          119        0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# 54                      Ostby, Mr. Engelhart Cornelius    male  65.0      0
# 62                         Harris, Mr. Henry Birkhardt    male  45.0      1
# 66                        Nye, Mrs. (Elizabeth Ramell)  female  29.0      0
# 75                             Moen, Mr. Sigurd Hansen    male  25.0      0
# 88                          Fortune, Miss. Mabel Helen  female  23.0      3
# 92                         Chaffee, Mr. Herbert Fuller    male  46.0      1
# 96                           Goldschmidt, Mr. George B    male  71.0      0
# 97                     Greenfield, Mr. William Bertram    male  23.0      0
# 102                          White, Mr. Richard Frasar    male  21.0      0
# 110                     Porter, Mr. Walter Chamberlain    male  47.0      0
# 118                           Baxter, Mr. Quigg Edmond    male  24.0      0
#
#      Parch       Ticket      Fare        Cabin Embarked   is_adult
# 1        0     PC 17599   71.2833          C85        C      adult
# 3        0       113803   53.1000         C123        S      adult
# 6        0        17463   51.8625          E46        S      adult
# 10       1      PP 9549   16.7000           G6        S  not_adult
# 11       0       113783   26.5500         C103        S      adult
# 21       0       248698   13.0000          D56        S      adult
# 23       0       113788   35.5000           A6        S      adult
# 27       2        19950  263.0000  C23 C25 C27        S  not_adult
# 52       0     PC 17572   76.7292          D33        C      adult
# 54       1       113509   61.9792          B30        C      adult
# 62       0        36973   83.4750          C83        S      adult
# 66       0   C.A. 29395   10.5000          F33        S      adult
# 75       0       348123    7.6500        F G73        S      adult
# 88       2        19950  263.0000  C23 C25 C27        S      adult
# 92       0  W.E.P. 5734   61.1750          E31        S      adult
# 96       0     PC 17754   34.6542           A5        C      adult
# 97       1     PC 17759   63.3583      D10 D12        C      adult
# 102      1        35281   77.2875          D26        S      adult
# 110      0       110465   52.0000         C110        S      adult
# 118      1     PC 17558  247.5208      B58 B60        C      adult

# %%
titanic_notnull.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# is_adult       0
# dtype: int64

# %%
titanic.isnull().sum() # 최대한 원본 파일 수정X
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# is_adult         0
# dtype: int64

# %%
# (inplace=True) 조건은 null drop한 상태로 데이터프레임 저장
temp = titanic.copy()
temp
temp.dropna(inplace=True)
temp[temp['Age'].isnull()].head() # 결측치 모두 제거했기 때문에 빈 데이터프레임
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, is_adult]
# Index: []

# %%
# .dropna(axis=1): null 값이 있는 열을 다 삭제
titanic_notnull = titanic.dropna(axis=1)
titanic_notnull # Age, Cabin, Embarked 열 모두 삭제된 것 확인 가능
# titanic_notnull[titanic_notnull['Age'].isnull()] -> Error
# Out:
#      PassengerId Survived  Pclass  \
# 0              1        0       3
# 1              2        1       1
# 2              3        1       3
# 3              4        1       1
# 4              5        0       3
# ..           ...      ...     ...
# 886          887        0       2
# 887          888        1       1
# 888          889        0       3
# 889          890        1       1
# 890          891        0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ..                                                 ...     ...    ...    ...
# 886                              Montvila, Rev. Juozas    male      0      0
# 887                       Graham, Miss. Margaret Edith  female      0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female      1      2
# 889                              Behr, Mr. Karl Howell    male      0      0
# 890                                Dooley, Mr. Patrick    male      0      0
#
#                Ticket     Fare   is_adult
# 0           A/5 21171   7.2500      adult
# 1            PC 17599  71.2833      adult
# 2    STON/O2. 3101282   7.9250      adult
# 3              113803  53.1000      adult
# 4              373450   8.0500      adult
# ..                ...      ...        ...
# 886            211536  13.0000      adult
# 887            112053  30.0000  not_adult
# 888        W./C. 6607  23.4500  not_adult
# 889            111369  30.0000      adult
# 890            370376   7.7500      adult
#
# [891 rows x 10 columns]

# %% [markdown]
# #### 4) unique

# %%
titanic.head()
# Out:
#    PassengerId Survived  Pclass  \
# 0            1        0       3
# 1            2        1       1
# 2            3        1       3
# 3            4        1       1
# 4            5        0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked is_adult
# 0      0         A/5 21171   7.2500   NaN        S    adult
# 1      0          PC 17599  71.2833   C85        C    adult
# 2      0  STON/O2. 3101282   7.9250   NaN        S    adult
# 3      0            113803  53.1000  C123        S    adult
# 4      0            373450   8.0500   NaN        S    adult

# %%
# unique 값 확인
titanic.Embarked.unique() #titanic['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %% [markdown]
# #### 5) value_counts

# %%
# unique 값 개수 확인
titanic.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# #### 6) groupby

# %%
titanic_sample = titanic[['Name', 'Age', 'Pclass', 'Fare', 'Sex']]
titanic_sample.head()
# Out:
#                                                 Name   Age  Pclass     Fare  \
# 0                            Braund, Mr. Owen Harris  22.0       3   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0       1  71.2833
# 2                             Heikkinen, Miss. Laina  26.0       3   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0       1  53.1000
# 4                           Allen, Mr. William Henry  35.0       3   8.0500
#
#       Sex
# 0    male
# 1  female
# 2  female
# 3  female
# 4    male

# %%
# size를 통해 해당 칼럼을 모은 후 개수 확인
titanic_sample.groupby("Pclass").size() # Pclass의 unique한 값들 즉 groupby를 통해서 의미있는 값들 볼 수있다
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# dtype: int64

# %%
# 2가지 기준으로 groupby한 후에 개수 확인
titanic_sample.groupby(["Pclass", "Sex"]).size()
# Out:
# Pclass  Sex
# 1       female     94
#         male      122
# 2       female     76
#         male      108
# 3       female    144
#         male      347
# dtype: int64

# %%
#Pclass에 따른 생존자 수를 확인하자 -> Pclass, Survived column 사용
#----------------------------------------------------------

#----------------------------------------------------------
# Out:
# Pclass  Survived
# 1       0            80
#         1           136
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# dtype: int64

# %%
# Pclass, Sex는 집계 기준이 되는 컬럼, Fare은 mean 구하는 컬럼
titanic_sample.groupby(["Pclass", "Sex"])['Fare'].mean()
# Out:
# Pclass  Sex
# 1       female    106.125798
#         male       67.226127
# 2       female     21.970121
#         male       19.741782
# 3       female     16.118810
#         male       12.661633
# Name: Fare, dtype: float64

# %%
# groupby로 모은 후 .agg를 통해 다양한 통계를 낼 수 있음 (min, max, mean, sum, median)
titanic_sample.groupby("Pclass").agg((["min","max","mean"]))
# Out:
#          Age                  Fare
#          min   max       mean  min       max       mean
# Pclass
# 1       0.92  80.0  38.233441  0.0  512.3292  84.154687
# 2       0.67  70.0  29.877630  0.0   73.5000  20.662183
# 3       0.42  74.0  25.140620  0.0   69.5500  13.675550

# %% [markdown]
# ## 3. 과제

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#1.서울버스노선이용자수, 서울버스정류소위치 파일 가져와서 각각 df1, df2에 저장합니다. 만약 한글이 깨질 경우 구글링해서 문제를 해결해보세요!
df1 = pd.read_csv('/content/drive/MyDrive/와이빅타 과제/서울버스노선이용자수.csv')
df2 = pd.read_csv('/content/drive/MyDrive/와이빅타 과제/서울버스정류소위치.csv')
# Out:
# <ipython-input-24-0e15bc50bd15>:2: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('/content/drive/MyDrive/와이빅타 과제/서울버스노선이용자수.csv')

# %%
#2. head()와 tail()을 통해 df1, df2 대략적으로 확인합니다, print말고 display 함수를 써보세요!
display(df1.head())
display(df1.tail())
display(df2.head())
display(df2.tail())
# Out:
#        기준일자 노선명  승차_정류장ARS     승차_정류장명  하차_정류장ARS   하차_정류장명  승차_정류장순번  \
# 0  20230521  17     3689.0     청암자이아파트     3255.0       용산역       1.0
# 1  20230521  17     3298.0  청암동강변삼성아파트     3122.0    한강대교북단       2.0
# 2  20230521  17     3298.0  청암동강변삼성아파트     3252.0  신용산.지하차도       2.0
# 3  20230521  17     3298.0  청암동강변삼성아파트     3255.0       용산역       2.0
# 4  20230521  17     3298.0  청암동강변삼성아파트     3294.0   서부이촌동입구       2.0
#
#    하차_정류장순번  승객수
# 0      12.0    9
# 1      14.0    3
# 2      11.0    2
# 3      12.0   19
# 4      15.0    2
#             기준일자  노선명  승차_정류장ARS     승차_정류장명  하차_정류장ARS   하차_정류장명  승차_정류장순번  \
# 430382  20230521  NaN        NaN  경성여객(기점가상)     7147.0    중랑초등학교       NaN
# 430383  20230521  NaN        NaN  경성여객(기점가상)     7151.0  상봉2동주민센터       NaN
# 430384  20230521  NaN        NaN  경성여객(기점가상)     7155.0     면목6거리       NaN
# 430385  20230521  NaN        NaN  경성여객(기점가상)     7189.0    용마공원입구       NaN
# 430386  20230521  NaN        NaN  경성여객(기점가상)     7191.0    면일초등학교       NaN
#
#         하차_정류장순번  승객수
# 430382      14.0    2
# 430383      12.0    1
# 430384      10.0    1
# 430385       4.0    1
# 430386       3.0    1
#      NODE_ID  ARS_ID           정류소명         X좌표        Y좌표
# 0  100000001    1001        종로2가사거리  126.987750  37.569765
# 1  100000002    1002    창경궁.서울대학교병원  126.996566  37.579183
# 2  100000003    1003      명륜3가.성대입구  126.998340  37.582671
# 3  100000004    1004       종로2가.삼일교  126.987613  37.568579
# 4  100000005    1005  혜화동로터리.여운형활동터  127.001744  37.586243
#          NODE_ID  ARS_ID         정류소명         X좌표        Y좌표
# 12565  124000334   25995        우성아파트  127.139338  37.550386
# 12566  124000333   25996        우성아파트  127.140046  37.550643
# 12567  124000332   25997         조일약국  127.123596  37.533630
# 12568  124000331   25998         성내시장  127.125497  37.536155
# 12569  124000330   25999  천호우체국.로데오거리  127.127337  37.540343

# %%
#3.각 데이터프레임의 정보를 확인합니다. (서울버스노선이용자수 데이터(df1)에 결측치가 있는 것을 확인할 수 있습니다)
print(df1.info())
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 430387 entries, 0 to 430386
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   기준일자       430387 non-null  int64
#  1   노선명        427603 non-null  object
#  2   승차_정류장ARS  429627 non-null  float64
#  3   승차_정류장명    430387 non-null  object
#  4   하차_정류장ARS  430222 non-null  float64
#  5   하차_정류장명    430366 non-null  object
#  6   승차_정류장순번   429640 non-null  float64
#  7   하차_정류장순번   430225 non-null  float64
#  8   승객수        430387 non-null  int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 29.6+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12570 entries, 0 to 12569
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   NODE_ID  12570 non-null  int64
#  1   ARS_ID   12570 non-null  int64
#  2   정류소명     12570 non-null  object
#  3   X좌표      12570 non-null  float64
#  4   Y좌표      12570 non-null  float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 491.1+ KB
# None

# %%
#4. df1의 노선명 column 중 결측치가 있는 행만 확인해봅니다.(index가 427603인 행부터 결함이 있다는 것을 확인할 수 있습니다.)
df1[df1['노선명'].isnull()]
# Out:
#             기준일자  노선명  승차_정류장ARS     승차_정류장명  하차_정류장ARS    하차_정류장명  승차_정류장순번  \
# 427603  20230521  NaN     7195.0    용마문화복지센터     1006.0    서대문역사거리       1.0
# 427604  20230521  NaN     7195.0    용마문화복지센터     1010.0        광화문       1.0
# 427605  20230521  NaN     7195.0    용마문화복지센터     1012.0       종로1가       1.0
# 427606  20230521  NaN     7195.0    용마문화복지센터     1014.0       종로2가       1.0
# 427607  20230521  NaN     7195.0    용마문화복지센터     1016.0  종로3가.탑골공원       1.0
# ...          ...  ...        ...         ...        ...        ...       ...
# 430382  20230521  NaN        NaN  경성여객(기점가상)     7147.0     중랑초등학교       NaN
# 430383  20230521  NaN        NaN  경성여객(기점가상)     7151.0   상봉2동주민센터       NaN
# 430384  20230521  NaN        NaN  경성여객(기점가상)     7155.0      면목6거리       NaN
# 430385  20230521  NaN        NaN  경성여객(기점가상)     7189.0     용마공원입구       NaN
# 430386  20230521  NaN        NaN  경성여객(기점가상)     7191.0     면일초등학교       NaN
#
#         하차_정류장순번  승객수
# 427603      36.0    1
# 427604      34.0    4
# 427605      33.0    2
# 427606      32.0    4
# 427607      31.0    6
# ...          ...  ...
# 430382      14.0    2
# 430383      12.0    1
# 430384      10.0    1
# 430385       4.0    1
# 430386       3.0    1
#
# [2784 rows x 9 columns]

# %%
# 개수가 2784개인 것을 보아 노선명에 결측치가 있는 행이 index가 427603~430386인 행이라고 추측할 수 있습니다.
print(df1.isnull().sum())
print('-'*50)
print(430386-427602)
# Out:
# 기준일자            0
# 노선명          2784
# 승차_정류장ARS     760
# 승차_정류장명         0
# 하차_정류장ARS     165
# 하차_정류장명        21
# 승차_정류장순번      747
# 하차_정류장순번      162
# 승객수             0
# dtype: int64
# --------------------------------------------------
# 2784

# %%
#5. df1에서 index가 427603인 행부터 삭제해서 새로운 df1을 만듭니다.
df1 = df1.loc[:427602]
df1
# Out:
#             기준일자   노선명  승차_정류장ARS     승차_정류장명  하차_정류장ARS    하차_정류장명  승차_정류장순번  \
# 0       20230521    17     3689.0     청암자이아파트     3255.0        용산역       1.0
# 1       20230521    17     3298.0  청암동강변삼성아파트     3122.0     한강대교북단       2.0
# 2       20230521    17     3298.0  청암동강변삼성아파트     3252.0   신용산.지하차도       2.0
# 3       20230521    17     3298.0  청암동강변삼성아파트     3255.0        용산역       2.0
# 4       20230521    17     3298.0  청암동강변삼성아파트     3294.0    서부이촌동입구       2.0
# ...          ...   ...        ...         ...        ...        ...       ...
# 427598  20230521  중랑02     7526.0       새마을금고     7527.0        공판장      23.0
# 427599  20230521  중랑02     7526.0       새마을금고     7528.0  진주빌라.바다약국      23.0
# 427600  20230521  중랑02     7526.0       새마을금고     7529.0  진로아파트앞.종점      23.0
# 427601  20230521  중랑02     7529.0   진로아파트앞.종점     7149.0   동부시장남문입구      26.0
# 427602  20230521  중랑02     7529.0   진로아파트앞.종점     7529.0  진로아파트앞.종점      26.0
#
#         하차_정류장순번  승객수
# 0           12.0    9
# 1           14.0    3
# 2           11.0    2
# 3           12.0   19
# 4           15.0    2
# ...          ...  ...
# 427598      24.0    1
# 427599      25.0    2
# 427600      26.0    5
# 427601      11.0    2
# 427602      26.0    1
#
# [427603 rows x 9 columns]

# %%
#아직 하차 정류장ARS와 하차_정류장 순번에 결측치가 있는 것을 확인할 수 있습니다.
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 427603 entries, 0 to 427602
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   기준일자       427603 non-null  int64
#  1   노선명        427603 non-null  object
#  2   승차_정류장ARS  426854 non-null  float64
#  3   승차_정류장명    427603 non-null  object
#  4   하차_정류장ARS  427439 non-null  float64
#  5   하차_정류장명    427582 non-null  object
#  6   승차_정류장순번   426867 non-null  float64
#  7   하차_정류장순번   427442 non-null  float64
#  8   승객수        427603 non-null  int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 29.4+ MB

# %%
#6. 이번에는 df1에서 결측치가 있는 행을 모두 제거해 새로운 df1을 만듭니다.
df1.dropna(inplace=True)
df1
# Out:
#             기준일자   노선명  승차_정류장ARS     승차_정류장명  하차_정류장ARS    하차_정류장명  승차_정류장순번  \
# 0       20230521    17     3689.0     청암자이아파트     3255.0        용산역       1.0
# 1       20230521    17     3298.0  청암동강변삼성아파트     3122.0     한강대교북단       2.0
# 2       20230521    17     3298.0  청암동강변삼성아파트     3252.0   신용산.지하차도       2.0
# 3       20230521    17     3298.0  청암동강변삼성아파트     3255.0        용산역       2.0
# 4       20230521    17     3298.0  청암동강변삼성아파트     3294.0    서부이촌동입구       2.0
# ...          ...   ...        ...         ...        ...        ...       ...
# 427598  20230521  중랑02     7526.0       새마을금고     7527.0        공판장      23.0
# 427599  20230521  중랑02     7526.0       새마을금고     7528.0  진주빌라.바다약국      23.0
# 427600  20230521  중랑02     7526.0       새마을금고     7529.0  진로아파트앞.종점      23.0
# 427601  20230521  중랑02     7529.0   진로아파트앞.종점     7149.0   동부시장남문입구      26.0
# 427602  20230521  중랑02     7529.0   진로아파트앞.종점     7529.0  진로아파트앞.종점      26.0
#
#         하차_정류장순번  승객수
# 0           12.0    9
# 1           14.0    3
# 2           11.0    2
# 3           12.0   19
# 4           15.0    2
# ...          ...  ...
# 427598      24.0    1
# 427599      25.0    2
# 427600      26.0    5
# 427601      11.0    2
# 427602      26.0    1
#
# [426725 rows x 9 columns]

# %%
# 결측치가 모두 없어진 것을 확인할 수 있습니다
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 426725 entries, 0 to 427602
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   기준일자       426725 non-null  int64
#  1   노선명        426725 non-null  object
#  2   승차_정류장ARS  426725 non-null  float64
#  3   승차_정류장명    426725 non-null  object
#  4   하차_정류장ARS  426725 non-null  float64
#  5   하차_정류장명    426725 non-null  object
#  6   승차_정류장순번   426725 non-null  float64
#  7   하차_정류장순번   426725 non-null  float64
#  8   승객수        426725 non-null  int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 32.6+ MB

# %%
#7. df1와 df2를 merge하기 위해 ARS의 data type을 통일할 것입니다. df1의 승차_정류장 ARS와 하차_정류장 ARS의 dtype을 float에서 int로 바꿉니다. (람다식 사용!)
df1['승차_정류장ARS'] = df1['승차_정류장ARS'].apply(lambda x: int(x))
df1['하차_정류장ARS'] = df1['하차_정류장ARS'].apply(lambda x: int(x))
df1
# Out:
#             기준일자   노선명  승차_정류장ARS     승차_정류장명  하차_정류장ARS    하차_정류장명  승차_정류장순번  \
# 0       20230521    17       3689     청암자이아파트       3255        용산역       1.0
# 1       20230521    17       3298  청암동강변삼성아파트       3122     한강대교북단       2.0
# 2       20230521    17       3298  청암동강변삼성아파트       3252   신용산.지하차도       2.0
# 3       20230521    17       3298  청암동강변삼성아파트       3255        용산역       2.0
# 4       20230521    17       3298  청암동강변삼성아파트       3294    서부이촌동입구       2.0
# ...          ...   ...        ...         ...        ...        ...       ...
# 427598  20230521  중랑02       7526       새마을금고       7527        공판장      23.0
# 427599  20230521  중랑02       7526       새마을금고       7528  진주빌라.바다약국      23.0
# 427600  20230521  중랑02       7526       새마을금고       7529  진로아파트앞.종점      23.0
# 427601  20230521  중랑02       7529   진로아파트앞.종점       7149   동부시장남문입구      26.0
# 427602  20230521  중랑02       7529   진로아파트앞.종점       7529  진로아파트앞.종점      26.0
#
#         하차_정류장순번  승객수
# 0           12.0    9
# 1           14.0    3
# 2           11.0    2
# 3           12.0   19
# 4           15.0    2
# ...          ...  ...
# 427598      24.0    1
# 427599      25.0    2
# 427600      26.0    5
# 427601      11.0    2
# 427602      26.0    1
#
# [426725 rows x 9 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12570 entries, 0 to 12569
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   NODE_ID  12570 non-null  int64
#  1   ARS_ID   12570 non-null  int64
#  2   정류소명     12570 non-null  object
#  3   X좌표      12570 non-null  float64
#  4   Y좌표      12570 non-null  float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 491.1+ KB

# %%
#8. df2에서 ARS_ID, X좌표, Y좌표 column만 선택해 df2_sample을 만듭니다.
df2_sample = df2[['ARS_ID', 'X좌표', 'Y좌표']]
df2_sample
# Out:
#        ARS_ID         X좌표        Y좌표
# 0        1001  126.987750  37.569765
# 1        1002  126.996566  37.579183
# 2        1003  126.998340  37.582671
# 3        1004  126.987613  37.568579
# 4        1005  127.001744  37.586243
# ...       ...         ...        ...
# 12565   25995  127.139338  37.550386
# 12566   25996  127.140046  37.550643
# 12567   25997  127.123596  37.533630
# 12568   25998  127.125497  37.536155
# 12569   25999  127.127337  37.540343
#
# [12570 rows x 3 columns]

# %%
# backup
# df1_copy = df1.copy()
# df2_copy = df2_sample.copy()

# %%
#9. ARS 번호를 이용하여 df1에 df2_sample을 merge해 '승차_정류장_X좌표', '승차_정류장_Y좌표', '하차_정류장_X좌표', '하차_정류장_Y좌표' 4개의 column을 추가하여 새로운 df1을 만듭니다
# merge할 때 inner 조인 방식을 사용합니다!
df1 = df1.merge(df2[['ARS_ID', 'X좌표', 'Y좌표']], left_on = '승차_정류장ARS', right_on='ARS_ID', how='inner')
df1.rename(columns={'X좌표': '승차_정류장_X좌표', 'Y좌표': '승차_정류장_Y좌표'}, inplace=True)
df1.drop('ARS_ID', axis=1, inplace=True)

df1 = df1.merge(df2[['ARS_ID', 'X좌표', 'Y좌표']], left_on='하차_정류장ARS', right_on='ARS_ID', how='inner')
df1.rename(columns={'X좌표': '하차_정류장_X좌표', 'Y좌표': '하차_정류장_Y좌표'}, inplace=True)
df1.drop('ARS_ID', axis=1, inplace=True)

df1
# Out:
#             기준일자   노선명  승차_정류장ARS     승차_정류장명  하차_정류장ARS     하차_정류장명  \
# 0       20230521    17       3689     청암자이아파트       3255         용산역
# 1       20230521    17       3298  청암동강변삼성아파트       3255         용산역
# 2       20230521    17       3321       청심경로당       3255         용산역
# 3       20230521    17       3304    원효2동주민센터       3255         용산역
# 4       20230521    17       3306         산천동       3255         용산역
# ...          ...   ...        ...         ...        ...         ...
# 378086  20230521  종로13       1829        부암슈퍼       1846       상명대입구
# 378087  20230521  종로13       1835         하림각       1874  국민은행.세검정지점
# 378088  20230521  종로13       1861      상명초등학교       1874  국민은행.세검정지점
# 378089  20230521  중랑01       7501       중화동종점       7506          수협
# 378090  20230521  중랑01       7501       중화동종점       7508        태릉시장
#
#         승차_정류장순번  하차_정류장순번  승객수  승차_정류장_X좌표  승차_정류장_Y좌표  하차_정류장_X좌표  \
# 0            1.0      12.0    9  126.946555   37.534547  126.965470
# 1            2.0      12.0   19  126.949318   37.533968  126.965470
# 2            3.0      12.0   32  126.950560   37.533706  126.965470
# 3            4.0      12.0   55  126.950950   37.534215  126.965470
# 4            5.0      12.0   72  126.954009   37.535339  126.965470
# ...          ...       ...  ...         ...         ...         ...
# 378086      22.0      25.0    1  126.963860   37.594760  126.957402
# 378087      23.0      35.0    1  126.962966   37.597685  126.960786
# 378088      28.0      35.0    1  126.956817   37.600905  126.960786
# 378089       1.0       4.0    2  127.082532   37.600060  127.079387
# 378090       1.0       5.0    1  127.082532   37.600060  127.078243
#
#         하차_정류장_Y좌표
# 0        37.528749
# 1        37.528749
# 2        37.528749
# 3        37.528749
# 4        37.528749
# ...            ...
# 378086   37.599854
# 378087   37.604887
# 378088   37.604887
# 378089   37.599553
# 378090   37.599772
#
# [378091 rows x 13 columns]

# %%
# backup
# df1_copy = df1.copy()

# %%
#10. 승차정류장의 좌표와 하차정류장의 좌표를 이용해 거리를 구하고 df1에 새로운 column '거리'를 추가해줍니다!
#경도와 위도 1도의 거리는 133.33km라 가정하고 피타고라스의 정리를 사용해 직선거리를 구합니다.
def distance(on_x, on_y, down_x, down_y):
  x_dist = on_x - down_x
  y_dist = on_y - down_y
  dist = (x_dist**2 + y_dist**2) **0.5
  dist *= 133.33
  return dist
df1['거리'] = df1.apply(lambda row: distance(row['승차_정류장_X좌표'], row['승차_정류장_Y좌표'], row['하차_정류장_X좌표'], row['하차_정류장_Y좌표']), axis=1)
df1
# Out:
#             기준일자   노선명  승차_정류장ARS     승차_정류장명  하차_정류장ARS     하차_정류장명  \
# 0       20230521    17       3689     청암자이아파트       3255         용산역
# 1       20230521    17       3298  청암동강변삼성아파트       3255         용산역
# 2       20230521    17       3321       청심경로당       3255         용산역
# 3       20230521    17       3304    원효2동주민센터       3255         용산역
# 4       20230521    17       3306         산천동       3255         용산역
# ...          ...   ...        ...         ...        ...         ...
# 378086  20230521  종로13       1829        부암슈퍼       1846       상명대입구
# 378087  20230521  종로13       1835         하림각       1874  국민은행.세검정지점
# 378088  20230521  종로13       1861      상명초등학교       1874  국민은행.세검정지점
# 378089  20230521  중랑01       7501       중화동종점       7506          수협
# 378090  20230521  중랑01       7501       중화동종점       7508        태릉시장
#
#         승차_정류장순번  하차_정류장순번  승객수  승차_정류장_X좌표  승차_정류장_Y좌표  하차_정류장_X좌표  \
# 0            1.0      12.0    9  126.946555   37.534547  126.965470
# 1            2.0      12.0   19  126.949318   37.533968  126.965470
# 2            3.0      12.0   32  126.950560   37.533706  126.965470
# 3            4.0      12.0   55  126.950950   37.534215  126.965470
# 4            5.0      12.0   72  126.954009   37.535339  126.965470
# ...          ...       ...  ...         ...         ...         ...
# 378086      22.0      25.0    1  126.963860   37.594760  126.957402
# 378087      23.0      35.0    1  126.962966   37.597685  126.960786
# 378088      28.0      35.0    1  126.956817   37.600905  126.960786
# 378089       1.0       4.0    2  127.082532   37.600060  127.079387
# 378090       1.0       5.0    1  127.082532   37.600060  127.078243
#
#         하차_정류장_Y좌표        거리
# 0        37.528749  2.637690
# 1        37.528749  2.263181
# 2        37.528749  2.094877
# 3        37.528749  2.068483
# 4        37.528749  1.762662
# ...            ...       ...
# 378086   37.599854  1.096694
# 378087   37.604887  1.003359
# 378088   37.604887  0.749608
# 378089   37.599553  0.424657
# 378090   37.599772  0.573168
#
# [378091 rows x 14 columns]

# %%
# backup
# df1_copy = df1.copy()

# %%
#11. 거리에 따라 내림차순으로 df1을 정렬하고 index를 초기화해줍니다. (제가 실수했는데.. index column도 없애주세요!)
df1.sort_values('거리', ascending=False, inplace=True)
df1.reset_index(drop=True, inplace=True)
df1
# Out:
#             기준일자   노선명  승차_정류장ARS              승차_정류장명  하차_정류장ARS  \
# 0       20230521   N26      16285                방화사거리       7550
# 1       20230521   160      10340           도봉산역광역환승센터      17184
# 2       20230521   N16      10005  서울북부지방법원.검찰청.도봉역성황당      17184
# 3       20230521   160      17185                  온수역      10006
# 4       20230521   N16      10009          도봉소방서.방학남부역      17290
# ...          ...   ...        ...                  ...        ...
# 378086  20230521  1218       9120               인수동장미원       9120
# 378087  20230521   144       9120               인수동장미원       9120
# 378088  20230521   109       9122                 가오리역       9122
# 378089  20230521  1120       9122                 가오리역       9122
# 378090  20230521  1139      10168             방학2동주민센터      10168
#
#                     하차_정류장명  승차_정류장순번  하차_정류장순번  승객수  승차_정류장_X좌표  승차_정류장_Y좌표  \
# 0               중랑공영차고지.신내역       4.0      67.0    1  126.810492   37.573086
# 1                       온수역       1.0      58.0    3  127.044352   37.689948
# 2                       온수역       4.0      68.0    1  127.044921   37.677775
# 3       서울북부지방법원.검찰청.도봉역성황당      60.0     116.0    1  126.824401   37.492777
# 4                     온수동종점       7.0      69.0    1  127.042981   37.666333
# ...                     ...       ...       ...  ...         ...         ...
# 378086               인수동장미원       8.0       8.0    9  127.015527   37.645033
# 378087               인수동장미원       8.0       8.0    6  127.015527   37.645033
# 378088                 가오리역       9.0       9.0    1  127.016578   37.641898
# 378089                 가오리역      32.0      32.0    1  127.016578   37.641898
# 378090             방학2동주민센터      31.0      31.0    1  127.034622   37.668271
#
#         하차_정류장_X좌표  하차_정류장_Y좌표         거리
# 0       127.103628   37.613209  39.448192
# 1       126.823823   37.492827  39.437362
# 2       126.823823   37.492827  38.432878
# 3       127.045103   37.677262  38.352746
# 4       126.821379   37.491922  37.599779
# ...            ...         ...        ...
# 378086  127.015527   37.645033   0.000000
# 378087  127.015527   37.645033   0.000000
# 378088  127.016578   37.641898   0.000000
# 378089  127.016578   37.641898   0.000000
# 378090  127.034622   37.668271   0.000000
#
# [378091 rows x 14 columns]

# %%
# backup
df1_copy = df1.copy()

# %%
#12. 노선당 몇 개의 경로가 있는지 그리고 각각의 경로 거리의 min, max, mean 값을 나타내봅니다.
df1_copy = df1_copy.groupby('노선명')['거리'].agg((["min","max","mean"]))
df1_copy
# Out:
#            min        max       mean
# 노선명
# 150   0.000000  37.099725   8.797148
# 151   0.000000  21.733298   5.833723
# 152   0.000000  26.128479   6.862455
# 160   0.000000  39.437362  10.943293
# 162   0.000000  16.976059   5.384766
# ...        ...        ...        ...
# 종로11  0.000000   4.233186   1.702398
# 종로12  0.000000   2.063608   0.979227
# 종로13  0.160305   2.239106   0.960189
# 중랑01  0.000000   2.021175   1.030255
# 중랑02  0.000000   3.410207   1.524621
#
# [617 rows x 3 columns]

# %%
#13. 최종적으로 df1을 csv파일로 만들어줍니다!
#csv 파일에서 한글이 깨지지 않도록 구글링해서 적용해주세요
####파일 2개
df1.to_csv("/content/drive/MyDrive/와이빅타 과제/df1.csv", index=False)
df1.to_csv("/content/drive/MyDrive/와이빅타 과제/df1_oneMore.csv", index=False)

# %% [markdown]
# **과제하시느라 수고하셨습니다!!!** <br>
# 과제는 실습과 과제 때 사용한 현 ipynb 파일과 최종 생성한 csv파일을 제출해주시면 됩니다!,<br>
# (ipynb,csv 파일명=> {이름}_pandas과제)
